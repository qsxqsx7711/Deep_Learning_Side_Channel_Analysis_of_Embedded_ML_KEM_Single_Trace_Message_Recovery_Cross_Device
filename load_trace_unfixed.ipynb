# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

import numpy as np

# %%
trace_num = 2000
order = '3'
opt = 'o3' # o0 or o3
scope = '' # _chipwhisperer or space
algo = 'PQClean' # orgPoly or PQClean or pqm4
platform = 'CW308_STM32F4' # CW308_STM32F3 or CW308_STM32F4 or CWLITEARM

trace_path = f'traces{scope}/{trace_num}/traces_unfixed_message_{trace_num}_{platform}_{opt}_{algo}_{order}'


t = np.load(f'{trace_path}/trace.npy')
m = np.load(f'{trace_path}/message.npy')

# %%
print(t.shape)
print(m.shape)
print(m)
t = np.load(f'trytrace.npy')

print(t[0])
# Out:
# (2000, 455000)
# (2000, 32)
# [[116. 224.  11. ...   5. 141.  26.]
#  [252.   7. 243. ...  58.  26.  43.]
#  [ 22.  73.   3. ... 166.  16. 124.]
#  ...
#  [101.  94. 126. ... 250.  70.  99.]
#  [  4.  99. 150. ... 140. 211. 153.]
#  [211. 254. 103. ...  72. 192.  66.]]
# [-0.13652179 -0.10181907  0.02139543 ...  0.02426444  0.03354291
#   0.04739958]

# %%
plt.rcParams.update({
    'font.family': 'serif',
    'font.serif': ['DejaVu Serif'],
    'mathtext.fontset': 'cm',   # 數學公式用 Computer Modern
})


plt.figure(figsize=(16, 8))
plt.rc('xtick', labelsize=14)   # x 軸刻度字體大小
plt.rc('ytick', labelsize=14)   # y 軸刻度字體大小

N = 455000
time = np.linspace(0, 910, N)  # 單位：µs

plt.xlabel(r'$\mathrm{Time} [\mu s]$' , fontsize=16)
plt.ylabel(r'$\mathrm{V}_{\mathrm{shunt}}$' , fontsize=16)


# plt.plot(time,t[0])
plt.plot(t[0])

plt.savefig(f'figure/load_trace/{platform}/{trace_num}/unfixed_message_single_trace.png', dpi=200, bbox_inches='tight')

# %%
plt.figure(figsize=(16, 8))
plt.rc('xtick', labelsize=14)   # x 軸刻度字體大小
plt.rc('ytick', labelsize=14)   # y 軸刻度字體大小
# plt.xlabel('Sample Points', fontsize=30)
# plt.ylabel('Power Consumption', fontsize=30)


N = 455000
time = np.linspace(0, 910, N)  # 單位：µs

plt.xlabel(r'$\mathrm{Time} [\mu s]$' , fontsize=16)
plt.ylabel(r'$\mathrm{V}_{\mathrm{shunt}}$' , fontsize=16)


# plt.plot(time,t[0])
plt.plot(time , np.mean(t, axis=0))
plt.savefig(f'figure/load_trace/{platform}/{trace_num}/unfixed_message_mean_trace.png', dpi=200, bbox_inches='tight')

# %%
N = 4_000_000
time = np.linspace(0, 910, N)  # 單位：µs

plt.plot(time, t)
plt.xlabel(r'$\mathrm{Time}\ (\mu s)$', fontsize=30)
plt.xlim(0, 910)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 N = 4_000_000
#       2 time = np.linspace(0, 910, N)  # 單位：µs
# ----> 4 plt.plot(time, t)
#       5 plt.xlabel(r'$\mathrm{Time}\ (\mu s)$', fontsize=30)
#       6 plt.xlim(0, 910)
#
# File ~/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...
